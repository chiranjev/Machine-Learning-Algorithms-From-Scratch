# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read an image

# %%
img = cv2.imread('images/dog1.jpg')
plt.imshow(img) # open cv uses BGR instead of RGB
plt.show()
newImg = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) 
plt.imshow(newImg)
plt.show()

# %%
img.shape
# Out:
# (162, 310, 3)
