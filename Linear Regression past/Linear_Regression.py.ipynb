# %% [markdown]
# ## Linear Regression

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Data - X (Acidity of milk) Y (Density of milk)

# %%
def readData(filename):
    df = pd.read_csv(filename)
    return df.values # returns array

x = readData('linearX.csv')
y = readData('linearY.csv')

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x.shape
y.shape
# Out:
# (99, 1)

# %%
x = x.reshape((99,))
y = y.reshape((99,))

# %% [markdown]
# ### Plot the data

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
x = (x-x.mean())/(x.std())

# %%
plt.scatter(x,y)

# %%
print(x.mean())
# Out:
# 3.801672781292203e-16

# %%
print(x.std())
# Out:
# 0.9999999999999999

# %%
x.mean()/x.std()
# Out:
# 3.8016727812922033e-16

# %%
x.mean()/(x.std())
# Out:
# 3.8016727812922033e-16

# %%
plt.scatter(x,y)

# %% [markdown]
# ## Algorithm - Linear Regression

# %%
def hypothesis(theta,x):
    return theta[0]+theta[1]*x

# %%
def error(X,Y,theta):
    m = x.shape[0]
    err = 0;
    for i in range(m):
        err+=(hypothesis(theta,X[i])-Y[i])**2
    return err/(2)

# %%
def gradient(theta,X,Y):
    grad = np.array([0.0,0.0])
    m = x.shape[0]
    err1 = 0
    err2 = 0;
    for i in range(m):
        err1 += (hypothesis(theta,X[i])-Y[i])
        err2 += (hypothesis(theta,X[i])-Y[i])*X[i]
    return np.array([err1,err2])

# %%
def gradientDescent(X,Y,learningRate,maxItr):
    theta = np.array([0.0,0.0])
    grad = np.array([0.0,0.0])
    
    for i in range(maxItr):
        grad = gradient(theta,X,Y)
        theta[0] = theta[0] - learningRate*grad[0]
        theta[1] = theta[1] - learningRate*grad[1]
    return theta

# %%
theta = gradientDescent(x,y,learningRate  = 0.001,maxItr = 100)
print(theta[0],theta[1])
# Out:
# 0.9966045602774349 0.0013578994635963

# %%
plt.scatter(x,y)
plt.plot(x,hypothesis(theta,x),color = 'r')

# %%
theta
# Out:
# array([0.99660456, 0.0013579 ])
